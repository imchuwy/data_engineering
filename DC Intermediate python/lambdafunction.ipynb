# %% [markdown]
# # Lambda functions
# They are anonymous functions
#
# Function type
# Lambda - If simple / performed once
# Custom - Complex / done multiple times
#
# # Example 1
# calculate_total = lambda x: x * (1 + extra_space)
# print(calculate_total(file_size))
#
#
# # Example 2
# print((lambda x: x * (1 + extra_space))(file_size))
#
#
# # Example 3 - Use MAP and LIST object
# colleagues = ["Sarah Martinez", "Michael Chen", "Emily Brown"]
# cleaned = map(lambda x: x.replace(" ", "_").lower(), colleagues)
#
# cleaned_list = list(cleaned)
# print(cleaned_list)

# %%
file_size = 2500
extra_space = 0.15

# Define a lambda function
calculate_total = lambda x: x * (1 + extra_space)

# Call the lambda function
print(calculate_total(file_size))

# Call a lambda function in one line
print((lambda x: x * (1 + extra_space))(file_size))

# %%
colleagues = ["Sarah Martinez", "Michael Chen", "Emily Brown"]

# Apply the lambda function to each colleague's name
cleaned = map(lambda x: x.replace(" ", "_").lower(), colleagues)

# Convert map object to list
cleaned_list = list(cleaned)
print(cleaned_list)

# %% [markdown]
# # Errors
# TypeError - Incompitable data type
# ValueError - Not in acceptable range
#
# # Error handling. except will still execute subsequent code. Raise will stop
# try: ...
#
# except: print("error message")
# or
# else:
#     raise: TypeError("error message")
#
# except will still execute subsequent code. Raise will stop
